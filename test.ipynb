# %%
a = ("name", "30","even sapir")
print(**a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 a = ("name", "30","even sapir")
# ----> 2 print(**a)
#       3
#
# TypeError: print() argument after ** must be a mapping, not tuple
